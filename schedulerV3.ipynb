# %%
from __future__ import print_function
import argparse
from ortools.sat.python import cp_model
from google.protobuf import text_format
import csv

# %%
# Define Room and Course class

class Room:
    def __init__(self, location, size, distance):

        self.location = location
        self.size = size
        self.distance = distance
        
class Course:
    def __init__(self, subject, courseNumber, title, version, section, instructor, day, capacity):

        self.subject = subject
        self.courseNumber = courseNumber
        self.title = title
        self.version = version
        self.section = section
        self.instructor = instructor 
        self.day = day
        self.capacity = capacity
        self.time = 0

# %%
def loadFiles(courses, location):
    
    # Read in classroom information, store each row's cell into the courses variables
    with open(courses) as csvDataFile:
        csvReader = csv.reader(csvDataFile, delimiter=',')

        # Omits the headers
        next(csvReader, None)

        # Note: Typcasting the "capacity" value to int
        for row in csvReader:
            courseTemp = Course(row[0],row[1],row[2],row[3],row[4],row[5],row[6],int(row[7]))
            course_arr.append(courseTemp)

    # Read in building information, store each row's cells into Classroom variables
    with open(location) as csvDataFile2:
        csvReader2 = csv.reader(csvDataFile2, delimiter = ',')

        # Omits the headers
        next(csvReader2, None)

        # Note: Typecasting the "size" value to int
        for rows in csvReader2:
            classroom = Room(rows[0],int(rows[1]),rows[2])
            class_arr.append(classroom)
            
    # Separate cell 'tt130' into day and time variables for each row
    for x in range(len(course_arr)):
        flag = 0
        
        # For each character in the string 'time'
        for l in range(len(course_arr[x].day)):
            if (flag == 0):
                # Breaks the 'time' string by character
                charNum =  ord(course_arr[x].day[l])
                
                # Is the current character a number?
                if charNum >= 48 and charNum <= 57:
                    # Adds class variable time, Update day variable
                    course_arr[x].time = course_arr[x].day[l:]
                    course_arr[x].day = course_arr[x].day[:l]
                    flag = 1

# %%
def SimpleSatProgram():

    # Declare the solver
    c_arr = []
    index = 0
    arrSize = len(class_arr) - 1

    # Create variables for scheduling problem
    for n in course_arr:
        name = 'course'+str(index)
        c_arr.append(model.NewIntVar(0, arrSize, name))
        index+=1
        

   # Define Constraints

   # Distance Constraint
   # Sort the room array by distance
   # Now the smaller indices have shorter distance from ITE Building
    dist_arr = []
    for n in class_arr:
        dist_arr.append(n.distance)
    dist_arr = sorted(dist_arr)
    class_sorted_arr = []
    for n in dist_arr:
        for x in class_arr:
            if(x.distance == n and x not in class_sorted_arr):
                class_sorted_arr.append(x)

    # Time Constraint
    countOne = -1
    countTwo = -1
    for n in course_arr:
        countOne += 1
        countTwo = -1
        for j in course_arr:
            countTwo += 1
            # Are the days the same?
            if course_arr[countOne].day == course_arr[countTwo].day:
               # Are the times the same?
               if course_arr[countOne].time == course_arr[countTwo].time and countOne != countTwo:
                  model.Add(c_arr[countOne] != c_arr[countTwo])


    # Size Constraint
    countOne = -1
    countTwo = -1
    for n in course_arr:
        countOne += 1
        countTwo = -1
        for j in class_sorted_arr:
            countTwo +=1
            # Will the class be able to fit into chosen classroom?
            if(course_arr[countOne].capacity > class_sorted_arr[countTwo].size):
                model.Add(c_arr[countOne] != countTwo)       
    
            
    # We want to minimize the distance since every class is CMSC
    # if we minimize that means we try to get the smaller indexes
    # which have the shorter distances
    for n in c_arr:
        model.Minimize(n)
    
    # cp model solver is used for scheduling programs                                                                             
    solver = cp_model.CpSolver()
    status = solver.Solve(model)

    count = 0
    # Outputs all optimal solutions
    for n in c_arr:
        if status == cp_model.OPTIMAL:
            print('-----------')
            val = solver.Value(n)
            print(course_arr[count].title);
            print("Room:", class_sorted_arr[val].location)
            print("Instructor:", course_arr[count].instructor)
            print("Day:", course_arr[count].day)
            print("Time:", course_arr[count].time)

            print('-----------')
            count +=1

# %%
if __name__ == "__main__" :
    model = cp_model.CpModel()
    course_arr = []
    class_arr = []

    # Files that needs to be loaded in
    # Note: If you need to load in a different file
    #       modify the variables below
    filePath = "D:/UMBC/CMSC 447/UMBC Scheduler/"
    fileOne = filePath + "classRoom.csv"
    fileTwo = filePath + "buildingLocation.csv"
    fileThree = filePath + "buildingLocationTwo.csv"
    
    # Loads in data
    loadFiles(fileOne, fileTwo)

    # Defines constraints and produces optimal solutions
    SimpleSatProgram()
# Out:
# -----------
# Problem Solving & Prog.
# Room: Biological Sciences 120
# Instructor: Staff
# Day: tt
# Time: 530
# -----------
# -----------
# Problem Solving & Prog.
# Room: Interdisciplinary Life S 233
# Instructor: Staff
# Day: mw
# Time: 530
# -----------
# -----------
# Computer Science I
# Room: Public Policy 105
# Instructor: Staff
# Day: mw
# Time: 230
# -----------
# -----------
# Computer Science I
# Room: Public Policy 105
# Instructor: Hamilton, Eric
# Day: mw
# Time: 1
# -----------
# -----------
# Computer Science I
# Room: Engineering 122, Engineering 122A
# Instructor: Johnson, Benjamin
# Day: tt
# Time: 1130
# -----------
# -----------
# Computer Science I
# Room: Public Policy 105
# Instructor: Hamilton, Eric
# Day: mw
# Time: 4
# -----------
# -----------
# Computer Science II
# Room: Public Policy 105
# Instructor: Dixon, Jeremy
# Day: tt
# Time: 10
# -----------
# -----------
# Computer Science II
# Room: Public Policy 105
# Instructor: Joeg, Prasanna
# Day: mw
# Time: 530
# -----------
# -----------
# Computer Science II
# Room: Public Policy 105
# Instructor: Donyaee, Kash
# Day: tt
# Time: 230
# -----------
# -----------
# Computer Science II
# Room: Public Policy 105
# Instructor: Donyaee, Kash
# Day: tt
# Time: 4
# -----------
# -----------
# Computer Science II
# Room: Engineering 122, Engineering 122A
# Instructor: Dixon, Jeremy
# Day: mw
# Time: 1
# -----------
# -----------
# Discrete Structures
# Room: Public Policy 105
# Instructor: Wilson, Marcella
# Day: tt
# Time: 530
# -----------
# -----------
# Discrete Structures
# Room: Math & Psychology 106
# Instructor: Hamilton, Eric
# Day: mw
# Time: 530
# -----------
# -----------
# Discrete Structures
# Room: Meyerhoff Chemistry 030
# Instructor: Yesha, Yaacov
# Day: tt
# Time: 10
# -----------
# -----------
# Discrete Structures
# Room: Interdisciplinary Life S 237
# Instructor: Yesha, Yaacov
# Day: tt
# Time: 1130
# -----------
# -----------
# Discrete Structures
# Room: Sherman Hall 013
# Instructor: Joeg, Prasanna
# Day: mw
# Time: 1
# -----------
# -----------
# Discrete Structures
# Room: Interdisciplinary Life S 237
# Instructor: Joeg, Prasanna
# Day: mw
# Time: 230
# -----------
# -----------
# Continued Computer Science for Non-Majors
# Room: Janet & Walter Sondheim 109
# Instructor: Staff
# Day: mw
# Time: 10
# -----------
# -----------
# Social & Ethical Issues in IT
# Room: Information Technology 227
# Instructor: Staff
# Day: tt
# Time: 530
# -----------
# -----------
# Social & Ethical Issues in IT
# Room: Meyerhoff Chemistry 030
# Instructor: Staff
# Day: tt
# Time: 710
# -----------
# -----------
# Social & Ethical Issues in IT
# Room: Meyerhoff Chemistry 030
# Instructor: Staff
# Day: mw
# Time: 530
# -----------
# -----------
# Social & Ethical Issues in IT
# Room: Information Technology 227
# Instructor: Staff
# Day: mw
# Time: 710
# -----------
# -----------
# Social & Ethical Issues in IT
# Room: Interdisciplinary Life S 237
# Instructor: Staff
# Day: tt
# Time: 530
# -----------
# -----------
# Social & Ethical Issues in IT
# Room: Interdisciplinary Life S 237
# Instructor: Staff
# Day: mw
# Time: 530
# -----------
# -----------
# Comp. Org. & Assembly Lang.
# Room: Math & Psychology 106
# Instructor: Sekyonda, Ivan
# Day: tt
# Time: 1130
# -----------
# -----------
# Comp. Org. & Assembly Lang.
# Room: Biological Sciences 120
# Instructor: Sekyonda, Ivan
# Day: tt
# Time: 4
# -----------
# -----------
# Comp. Org. & Assembly Lang.
# Room: Math & Psychology 106
# Instructor: Kartchner, Jeannette
# Day: mw
# Time: 1
# -----------
# -----------
# Comp. Org. & Assembly Lang.
# Room: Math & Psychology 106
# Instructor: Sekyonda, Ivan
# Day: mw
# Time: 230
# -----------
# -----------
# Programming Languages
# Room: Janet & Walter Sondheim 109
# Instructor: Donyaee, Kash
# Day: tt
# Time: 10
# -----------
# -----------
# Programming Languages
# Room: Interdisciplinary Life S 237
# Instructor: Vafaei, Fereydoon
# Day: tt
# Time: 1
# -----------
# -----------
# Programming Languages
# Room: Sherman Hall 014
# Instructor: Donyaee, Kash
# Day: mw
# Time: 1
# -----------
# -----------
# Programming Languages
# Room: Interdisciplinary Life S 237
# Instructor: Vafaei, Fereydoon
# Day: tt
# Time: 4
# -----------
# -----------
# Data Structures
# Room: Engineering 122, Engineering 122A
# Instructor: Marron, Christopher
# Day: mw
# Time: 10
# -----------
# -----------
# Data Structures
# Room: Math & Psychology 106
# Instructor: Wilson, Marcella
# Day: tt
# Time: 1
# -----------
# -----------
# Data Structures
# Room: Math & Psychology 106
# Instructor: Wilson, Marcella
# Day: tt
# Time: 230
# -----------
# -----------
# Data Structures
# Room: Interdisciplinary Life S 233
# Instructor: Johnson, Benjamin
# Day: mw
# Time: 1
# -----------
# -----------
# Data Structures
# Room: Meyerhoff Chemistry 030
# Instructor: Bargteil, Adam
# Day: mw
# Time: 230
# -----------
# -----------
# Data Structures
# Room: Janet & Walter Sondheim 109
# Instructor: Johnson, Benjamin
# Day: mw
# Time: 4
# -----------
# -----------
# Computer Architecture
# Room: Janet & Walter Sondheim 109
# Instructor: Squire, Jon
# Day: tt
# Time: 230
# -----------
# -----------
# Computer Architecture
# Room: Biological Sciences 120
# Instructor: Sekyonda, Ivan
# Day: mw
# Time: 1
# -----------
# -----------
# Computer Architecture
# Room: Janet & Walter Sondheim 109
# Instructor: Olano, Marc
# Day: mw
# Time: 230
# -----------
# -----------
# Computer Architecture
# Room: Engineering 122, Engineering 122A
# Instructor: Staff
# Day: tt
# Time: 530
# -----------
# -----------
# Operating Systems
# Room: Information Technology 227
# Instructor: Staff
# Day: tt
# Time: 1130
# -----------
# -----------
# Operating Systems
# Room: Information Technology 227
# Instructor: Perkins, Dmitri
# Day: tt
# Time: 230
# -----------
# -----------
# Operating Systems
# Room: Janet & Walter Sondheim 109
# Instructor: Staff
# Day: mw
# Time: 530
# -----------
# -----------
# Computer Security
# Room: Meyerhoff Chemistry 030
# Instructor: Staff
# Day: tt
# Time: 1
# -----------
# -----------
# Computer Security
# Room: Math & Psychology 106
# Instructor: Staff
# Day: tt
# Time: 4
# -----------
# -----------
# Computer Graphics
# Room: Interdisciplinary Life S 237
# Instructor: Olano, Marc
# Day: mw
# Time: 1
# -----------
# -----------
# Algorithms
# Room: Janet & Walter Sondheim 109
# Instructor: Chang, Richard
# Day: tt
# Time: 1
# -----------
# -----------
# Algorithms
# Room: Engineering 122, Engineering 122A
# Instructor: Chang, Richard
# Day: tt
# Time: 10
# -----------
# -----------
# Algorithms
# Room: Information Technology 227
# Instructor: Marron, Christopher
# Day: mw
# Time: 10
# -----------
# -----------
# Cryptography and Data Security
# Room: Information Technology 227
# Instructor: Zhang, Haibin
# Day: tt
# Time: 10
# -----------
# -----------
# Software Engineering I
# Room: Meyerhoff Chemistry 030
# Instructor: Dutt, Abhijit
# Day: mw
# Time: 1
# -----------
# -----------
# Software Engineering I
# Room: Engineering 122, Engineering 122A
# Instructor: Dutt, Abhijit
# Day: mw
# Time: 230
# -----------
# -----------
# Software Engineering I
# Room: Math & Psychology 106
# Instructor: Staff
# Day: tt
# Time: 530
# -----------
# -----------
# Software Engineering I
# Room: Janet & Walter Sondheim 109
# Instructor: Staff
# Day: tt
# Time: 710
# -----------
# -----------
# Numerical Computations
# Room: Math & Psychology 106
# Instructor: Squire, Jon
# Day: mw
# Time: 4
# -----------
# -----------
# Databases
# Room: Meyerhoff Chemistry 030
# Instructor: Kalpakis, Kostas
# Day: tt
# Time: 1130
# -----------
# -----------
# Databases
# Room: Information Technology 227
# Instructor: Staff
# Day: mw
# Time: 230
# -----------
# -----------
# Artificial Intelligence
# Room: Meyerhoff Chemistry 030
# Instructor: Vafaei, Fereydoon
# Day: mw
# Time: 4
# -----------
# -----------
# Artificial Intelligence
# Room: Meyerhoff Chemistry 030
# Instructor: Finin, Tim
# Day: tt
# Time: 4
# -----------
# -----------
# Artificial Intelligence
# Room: Engineering 122, Engineering 122A
# Instructor: Staff
# Day: mw
# Time: 530
# -----------
# -----------
# Information Retrieval
# Room: Janet & Walter Sondheim 109
# Instructor: Pearce, Claudia
# Day: mw
# Time: 1
# -----------
# -----------
# Machine Learning
# Room: Janet & Walter Sondheim 109
# Instructor: Vafaei, Fereydoon
# Day: tt
# Time: 1130
# -----------
# -----------
# Introduction to Robotics
# Room: Meyerhoff Chemistry 030
# Instructor: Matuszek, Cynthia
# Day: tt
# Time: 230
# -----------
# -----------
# Computer Networks
# Room: Janet & Walter Sondheim 109
# Instructor: Sidhu, Deepinder
# Day: tt
# Time: 4
# -----------
# -----------
# Spec Topic: Quantum Security
# Room: Information Technology 227
# Instructor: Sidhu, Deepinder
# Day: tt
# Time: 710
# -----------
# -----------
# Parallel & Distr. Processing
# Room: Meyerhoff Chemistry 030
# Instructor: Simon, Tyler
# Day: tt
# Time: 530
# -----------
# -----------
# Network Security
# Room: Engineering 122, Engineering 122A
# Instructor: Zieglar, Edward
# Day: tt
# Time: 710
# -----------
# -----------
# Spec Topic: Malware
# Room: Information Technology 227
# Instructor: Nicholas, Charles
# Day: mw
# Time: 530
# -----------
# -----------
# Spec Topic: Computer Vision
# Room: Engineering 122, Engineering 122A
# Instructor: Chapman, David
# Day: tt
# Time: 4
# -----------
# -----------
# Spec Topic: Data Science
# Room: Engineering 122, Engineering 122A
# Instructor: Dutt, Abhijit
# Day: mw
# Time: 4
# -----------
# -----------
# Games Capstone
# Room: Engineering 122, Engineering 122A
# Instructor: staff
# Day: tt
# Time: 1
# -----------
# -----------
# Computer Architecture
# Room: Information Technology 227
# Instructor: Liu, Chenchen
# Day: tt
# Time: 4
# -----------
# -----------
# Operating Systems
# Room: Information Technology 227
# Instructor: Kalpakis, Kostas
# Day: tt
# Time: 1
# -----------
# -----------
# Algorithms
# Room: Information Technology 227
# Instructor: Sherman, Alan
# Day: MWF
# Time: 10
# -----------
# -----------
# Machine Learning
# Room: Engineering 122, Engineering 122A
# Instructor: Oates, Tim
# Day: tt
# Time: 230
# -----------
# -----------
# Network Technologies
# Room: Janet & Walter Sondheim 109
# Instructor: Sidhu, Deepinder
# Day: tt
# Time: 530
# -----------
# -----------
# Wireless Sensor Networks
# Room: Information Technology 227
# Instructor: Younis, Mohamed
# Day: MW
# Time: 230
# -----------
# -----------
# Spec Topic: Graphical and Statistical Models of Learning
# Room: Information Technology 227
# Instructor: Ferraro, Frank
# Day: mw
# Time: 4
# -----------
# -----------
# Spec Topic: Data Driven Design of Autonmous Systems
# Room: Information Technology 227
# Instructor: Zhu, Ting
# Day: mw
# Time: 1
# -----------
